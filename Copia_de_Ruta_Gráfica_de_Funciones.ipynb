# %% [markdown]
# <a href="https://colab.research.google.com/github/YasminGarcia1210/CURSO-DE-ALGEBRA-Y-FUNCIONES-/blob/main/Copia_de_Ruta_Gr%C3%A1fica_de_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src=https://upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Logo_de_la_Universidad_ICESI.svg/2560px-Logo_de_la_Universidad_ICESI.svg.png width="300" height="100" align="center">
#
# #**<big><big>ÁLGEBRA Y FUNCIONES</big></big><br><small>Departamento de Pensamiento Lógico y Matemático. </small><br><small>Ruta: gráfica de funciones.</small>**

# %% [markdown]
# ##OBJETIVO:
# Analizar para una función sus elementos fundamentales tales como: dominio, rango, ceros, asíntotas, intervalos de crecimiento e intervalos donde la función es positiva o negativa. Utilizar diferentes tipos de registro de representación de una función para resolver situaciones problema

# %% [markdown]
# ### Elementos a tener en cuenta para Analizar la grafica de una función
#
# * Una función es una relación entre dos variables x e y, de modo que, a cada valor de la variable independiente, x, le asocia un único valor de la variable  dependiente y.
# * El dominio de una función es el conjunto de todos los posibles valores que puede tomar x.
# * La gráfica de una función es el conjunto de puntos $ (x,f(x))$  representados en el plano.
# * Una función es continua si puede representarse con un solo trazo. Es discontinua en un punto si presenta un "salto", un "huequito" o asíntota.
# * Una función es simétrica respecto al eje Y, o  función par, si $f(x)=f(-x)$; y es simétrica respecto al origen, función impar, si $f(-x)=-f(x)$
# * Una función es creciente en un intervalo, cuando dados dos puntos cualesquiera del mismo Si $ x_1<x_2$  entonces $f(x_1)<f(x_2)$ y decreciente si $x_1<x_2$ entonces $ f(x_1)>f(x_2)$

# %% [markdown]
# # Antes de Clases

# %% [markdown]
# 1. Explorar el siguiente recurso en Python. Moviendo el deslizador responda:
#
# * ¿Qué tipo de grafica se tiene?
# * Cuando se mueve el deslizador ¿Qué varía en la grafica?
# * ¿Qué impacto tiene el concepto de pendiente en la grafica?

# %%
import matplotlib.pyplot as plt
from ipywidgets import interact

def graficar_lineal(pendiente):
    x = range(-10, 11)
    y = [pendiente * xi for xi in x]

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label=f'Pendiente: {pendiente}', color='blue')
    plt.title('Función Lineal')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.legend()
    plt.show()

# Utilizando ipywidgets para crear un control deslizante interactivo
interact(graficar_lineal, pendiente=(-10, 10, 0.5))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='pendiente', max=10.0, min=-10.0, step=0.5), Output()…
# <function __main__.graficar_lineal(pendiente)>

# %% [markdown]
# # Grafica de la función lineal
#
# Explore dando valores a la pendiente y el intercepto y reflexione sobre el comportamiento de la grafica de la linea

# %%
# @title FUNCIÓN LINEAL  { run: "auto", vertical-output: true }
pendiente = 1 # @param {type:"number"}
intercepto = 5 # @param {type:"number"}

# Crear datos x e y para la línea
x = range(-10, 11)  # Puedes ajustar el rango según tus necesidades
y = [pendiente * i + intercepto for i in x]

# Graficar la línea
plt.plot(x, y, label=f'Línea: y = {pendiente}x + {intercepto}')

# Agregar etiquetas y título
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.axvline(x=0, color='black') #Eje y
plt.axhline(y=0, color='black') #Eje x
plt.title('Gráfica de una línea')

# Mostrar la leyenda
plt.legend()

# Mostrar la gráfica
plt.grid(True)
plt.show()

# %% [markdown]
# 2. Dada  la siguiente función: $f(x)=x^2+1$
#
# * Complete la siguiente tabla
#
#
# \begin{array}{|c|c|}
# \hline
# \text{Eje x} & \text{Eje y } \\
# \hline
# 1 &  \\
# 2 & \\
# 3 &  \\
# 4 & \\
# 5 & \\
# \hline
# \end{array}

# %%
#Usando Python
import numpy as np
x=np.linspace(1,5,5) # Aqui tenemos los Valores del 1 al 5

y=[x**2+1 for x in x] # Aqui calculamos los valores de x evaluados en la función

#generamos las parejas prdenadas
pairs = list(zip(x, y))
print(pairs)
# Out:
# [(1.0, 2.0), (2.0, 5.0), (3.0, 10.0), (4.0, 17.0), (5.0, 26.0)]

# %% [markdown]
# # Despues de la clase

# %% [markdown]
# # Resolver los siguiente ejercicios con ayuda de tu profesor.

# %% [markdown]
# ## Sección 1.2
#
# \begin{array}{|c|c|}
# \hline
# \text{Columna 1 } & \text{Columna 2} \\
# \hline
# 7-8-9 &  10-11-12\\
#  16&17 \\
#  81&  83\\
# 87& 88\\
# \hline
# \end{array}

# %% [markdown]
# # Explorar el siguiente recurso y responder las preguntas que tiene

# %%
#@title Ver applet GG {display-mode: "form"}

import IPython.display as IP

iframe = IP.IFrame(src="https://www.geogebra.org/m/vesvzf7d",width="900px",height="600px")

IP.display_html(iframe)
# Out:
#         <iframe
#             width="900px"
#             height="600px"
#             src="https://www.geogebra.org/m/vesvzf7d"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Recurso Adicional
#
# Observe lo que sucede en el grafico al variar los valores de a,b y c en la función cuadrática

# %%
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact

def graficar_cuadratica(a, b, c):
    x = np.linspace(-10, 10, 100)
    y = a * x**2 + b * x + c

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label=f'{a}x^2 + {b}x + {c}', color='red')
    plt.title('Función Cuadrática')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.axhline(0, color='black', linewidth=0.5)
    plt.axvline(0, color='black', linewidth=0.5)
    plt.grid(color='gray', linestyle='--', linewidth=0.5)
    plt.legend()
    plt.show()

#Creando el deslizador
interact(graficar_cuadratica, a=(-5, 5, 0.1), b=(-5, 5, 0.1), c=(-5, 5, 0.1))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='a', max=5.0, min=-5.0), FloatSlider(value=0.0, descr…
# <function __main__.graficar_cuadratica(a, b, c)>

# %%
print("i just want to pass this matter")
# Out:
# i just want to pass this matter

# %% [markdown]
# <img src=https://upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Logo_de_la_Universidad_ICESI.svg/2560px-Logo_de_la_Universidad_ICESI.svg.png width="300" height="100" align="center">
#
# #**<big><big>ÁLGEBRA Y FUNCIONES</big></big><br><small>** Departamento de Pensamiento Lógico y Matemático </small><br><small>Ruta: Factorización y Simplificación de expresiones racionales

# %% [markdown]
# ## **Secciones**
#
#
# [Sesión del libro](https://drive.google.com/file/d/1-onRWQvaceZ0y0gSjegvaPBTCCYQFsER/view?usp=sharing)
# * 2.7 Factorización de Polinomios
# * 2.8 Expresiones racionales
#
#
# ## **Objetivo**
#
# Fortalecer el pensamiento crítico y la resolución de problemas mediante la identificación de expresiones algebraicas, ecuaciones y factorización, para mejorar la comprensión y habilidades fundamentales en álgebra.

# %% [markdown]
# ### Antes de Clase
#
# 1. Indaga sobre las operaciones de suma, resta y multiplicación entre polinomios y escriba un ejemplo de cada una de ellas.
# 2. Averigua qué es un producto notable, establezca la relación con la factorización y use un producto notable para operar $(3n-k)^3$
# 3.  A partir de los siguientes videos

# %% [markdown]
# # Video 1

# %%
#@title.Relación matemáticas y Computación  {display-mode:"form"}
from IPython.display import YouTubeVideo

YouTubeVideo("ROGt8u81FxM" , width=600, height=450)

# %% [markdown]
# # Video 2

# %%
#@title.Factorización {display-mode:"form"}
from IPython.display import YouTubeVideo
YouTubeVideo("7fhO4Qj7X1c" , width=600, height=450)

# %% [markdown]
# ### Responde
#
# a. ¿Qué es Factorizar un polinomio?
#
# b. Factoriza la siguiente expresión $(a+b)^2-c^2$ tal como se muestra en el video
#
# c. Investiga la manera de factorizar los trinomios, la suma y diferencia de cubos (Potencias en el video)
#
# 4.  Simplifica la siguiente expresión, escribe cada paso
#
# $$\frac{x^2-6x+9}{x^2+2x-15} \div \frac{2x-10}{x^2-25} $$
#
#
# 5. A partir del siguiente [video]( https://www.youtube.com/watch?v=E4eOl33N09k), inventa y resuelve una situación donde se deba usar el algoritmo de la división. Reta en clase a tus compañeros a que la resuelvan.

# %% [markdown]
# ## Despues de clase
# Realizar los ejercicios de la columna C1 para socializar en clase, la columna C2 se proponen como ejercicios de práctica.
#
# * Sesión 2.7
#
# \begin{array}{|c|c|}
# \hline
# \text{C1} & \text{C2} \\
# \hline
# 5 & 6 \\
# 14 & 15 \\
# 32 & 36 \\
# 43 & 52 \\
# \hline
# \end{array}
#
# * Sesión 2.8
#
# \begin{array}{|c|c|}
# \hline
# \text{C1} & \text{C2} \\
# \hline
# 4 & 5 \\
# 11 & 12 \\
# 24 & 26 \\
# 46 & 49 \\
# \hline
# \end{array}

# %% [markdown]
# # **Presentación del siguiente Tema**
#
# ## Ecuaciones
#
# [Libro guia](https://drive.google.com/file/d/1uezlhVze0c7kjF9jif8Y9f67cgYuX1hz/view?usp=sharing)
#
# ## **Secciones**
#
# * 3.1 Introducción
# * 3.2 Traducción de palabras a una ecuación
# * 3.3 Ecuaciones Cuadráticas

# %% [markdown]
# <img src="https://img.freepik.com/vector-gratis/hombre-negocios-tiene-idea_1133-350.jpg?size=338&ext=jpg&ga=GA1.1.1412446893.1705968000&semt=ais" width="150" height="150" align="left">
#
# Decimos que dos ecuaciones son equivalentes si tienen
# las mismas soluciones, es decir, si sus conjuntos solución son exactamente iguales
#
# Explique por que las siguientes ecuaciones son equivalentes
#
# $2x-1=0$; $2x=1$ y $x=1/2$

# %% [markdown]
# <img src="https://previews.123rf.com/images/dualororua/dualororua1801/dualororua180100141/92769889-ni%C3%B1o-peque%C3%B1o-de-dibujos-animados-jugando-tenis-en-un-fondo-blanco.jpg" width="150" height="150" align="left">¿Alguien quiere jugar tenis? La velocidad v en pies/
# segundo de una pelota de tenis $t$  segundos después de que
# se lanzó hacia arriba con una velocidad inicial de 8 pies/s
# está dada por  $v=-32t + 8$. ¿Cuántos segundos han transcurrido
# cuando
# a) $v =4$ pies/s  y
# b) $v =0$ pies/s?
